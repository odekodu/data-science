# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/epl_matches.csv')
df.head()
# Out:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result  gf  ga  ...  match report  notes    sh   sot  pk   fk pkatt  dist  \
# 0      L   0   1  ...  Match Report    NaN  18.0   4.0   0  1.0     0  17.3
# 1      W   5   0  ...  Match Report    NaN  16.0   4.0   0  1.0     0  18.5
# 2      W   5   0  ...  Match Report    NaN  25.0  10.0   0  0.0     0  14.8
# 3      W   1   0  ...  Match Report    NaN  25.0   8.0   0  0.0     0  14.3
# 4      D   0   0  ...  Match Report    NaN  16.0   1.0   0  1.0     0  16.4
#
#                name season
# 0  Manchester City    2022
# ...

# %%
# Rename column name to team
df.rename(columns= { 'name': 'team' }, inplace= True)

# %%
# Remove trailing spaces from the team name
df['team'] = df['team'].str.strip()

# %%
df[df['team'] == 'Liverpool']
# Out:
#      Unnamed: 0        date   time            comp         round  day venue  \
# 38            0  2021-08-14  17:30  Premier League   Matchweek 1  Sat  Away
# 39            1  2021-08-21  12:30  Premier League   Matchweek 2  Sat  Home
# 40            2  2021-08-28  17:30  Premier League   Matchweek 3  Sat  Home
# 41            3  2021-09-12  16:30  Premier League   Matchweek 4  Sun  Away
# 42            5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home
# ..          ...         ...    ...             ...           ...  ...   ...
# 869          48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home
# 870          49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away
# 871          50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away
# 872          51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away
# 873          52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home
#
# ...

# %%
df['round'].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 29    40
# Matchweek 22    40
# Matchweek 23    40
# Matchweek 24    40
# Matchweek 25    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 28    40
# Matchweek 31    40
# Matchweek 2     40
# Matchweek 32    40
# Matchweek 30    40
# Matchweek 34    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 33    40
# Matchweek 37    40
# Matchweek 21    40
# Matchweek 20    40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 16    40
# Matchweek 17    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
# Convert date from string to pd.datetime
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                        int64
# ga                        int64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# pk                        int64
# fk                      float64
# pkatt                     int64
# dist                    float64
# team                     object
# season                    int64
# ...

# %%
# Create a simple predictor
df['venue_code'] = df['venue'].astype('category').cat.codes

# %%
df.head()
# Out:
#    Unnamed: 0       date   time            comp        round  day venue  \
# 0           1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result  gf  ga  ... notes    sh   sot  pk   fk pkatt  dist             team  \
# 0      L   0   1  ...   NaN  18.0   4.0   0  1.0     0  17.3  Manchester City
# 1      W   5   0  ...   NaN  16.0   4.0   0  1.0     0  18.5  Manchester City
# 2      W   5   0  ...   NaN  25.0  10.0   0  0.0     0  14.8  Manchester City
# 3      W   1   0  ...   NaN  25.0   8.0   0  0.0     0  14.3  Manchester City
# 4      D   0   0  ...   NaN  16.0   1.0   0  1.0     0  16.4  Manchester City
#
#   season venue_code
# 0   2022          0
# 1   2022          1
# ...

# %%
df['opp_code'] = df['opponent'].astype('category').cat.codes
df.head()
# Out:
#    Unnamed: 0       date   time            comp        round  day venue  \
# 0           1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result  gf  ga  ...    sh   sot  pk   fk  pkatt  dist             team  \
# 0      L   0   1  ...  18.0   4.0   0  1.0      0  17.3  Manchester City
# 1      W   5   0  ...  16.0   4.0   0  1.0      0  18.5  Manchester City
# 2      W   5   0  ...  25.0  10.0   0  0.0      0  14.8  Manchester City
# 3      W   1   0  ...  25.0   8.0   0  0.0      0  14.3  Manchester City
# 4      D   0   0  ...  16.0   1.0   0  1.0      0  16.4  Manchester City
#
#   season venue_code opp_code
# 0   2022          0       18
# 1   2022          1       15
# ...

# %%
df['hour'] = df['time'].replace(':.+', '', regex= True).astype('int')
df.head()
# Out:
#    Unnamed: 0       date   time            comp        round  day venue  \
# 0           1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result  gf  ga  ...   sot  pk   fk  pkatt  dist             team season  \
# 0      L   0   1  ...   4.0   0  1.0      0  17.3  Manchester City   2022
# 1      W   5   0  ...   4.0   0  1.0      0  18.5  Manchester City   2022
# 2      W   5   0  ...  10.0   0  0.0      0  14.8  Manchester City   2022
# 3      W   1   0  ...   8.0   0  0.0      0  14.3  Manchester City   2022
# 4      D   0   0  ...   1.0   0  1.0      0  16.4  Manchester City   2022
#
#   venue_code opp_code hour
# 0          0       18   16
# 1          1       15   15
# ...

# %%
df['day_code'] = df['date'].dt.day_of_week
df.head()
# Out:
#    Unnamed: 0       date   time            comp        round  day venue  \
# 0           1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result  gf  ga  ... pk   fk  pkatt  dist             team season venue_code  \
# 0      L   0   1  ...  0  1.0      0  17.3  Manchester City   2022          0
# 1      W   5   0  ...  0  1.0      0  18.5  Manchester City   2022          1
# 2      W   5   0  ...  0  0.0      0  14.8  Manchester City   2022          1
# 3      W   1   0  ...  0  0.0      0  14.3  Manchester City   2022          0
# 4      D   0   0  ...  0  1.0      0  16.4  Manchester City   2022          1
#
#   opp_code hour day_code
# 0       18   16        6
# ...

# %%
df['target'] = (df['result'] == 'W').astype('int')
df.head()
# Out:
#    Unnamed: 0       date   time            comp        round  day venue  \
# 0           1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result  gf  ga  ...   fk  pkatt  dist             team  season venue_code  \
# 0      L   0   1  ...  1.0      0  17.3  Manchester City    2022          0
# 1      W   5   0  ...  1.0      0  18.5  Manchester City    2022          1
# 2      W   5   0  ...  0.0      0  14.8  Manchester City    2022          1
# 3      W   1   0  ...  0.0      0  14.3  Manchester City    2022          0
# 4      D   0   0  ...  1.0      0  16.4  Manchester City    2022          1
#
#   opp_code hour day_code target
# 0       18   16        6      0
# ...

# %%
df['result'].astype('category').cat.codes
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       0
#        ..
# 1515    1
# 1516    1
# 1517    2
# 1518    1
# 1519    2
# Length: 1520, dtype: int8

# %%
# Creating the machine learning model
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators= 50, min_samples_split= 10)

# %%
train = df[df['date'] < '2022-01-01']

# %%
test = df[df['date'] >= '2022-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50)

# %%
prediction = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], prediction)

# %%
acc
# Out:
# 0.5964467005076142

# %%
combined = pd.DataFrame(dict(actual= test['target'], prediction= prediction))

# %%
pd.crosstab(index=combined['actual'], columns= combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           187  49
# 1           110  48

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], prediction)
# Out:
# 0.4948453608247423

# %%
grouped_matches = df.groupby('team')

# %%
group = grouped_matches.get_group('Manchester City')

# %%
#group

# %%
# What was the performance (average) in the n previous matches 

def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')

    # Include only the past 3 days data
    rolling_stats = group[cols].rolling(3, closed= 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset= new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#      Unnamed: 0       date   time            comp         round  day venue  \
# 763           5 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home
# 764           7 2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away
# 765           9 2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away
# 766          11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home
# 767          12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away
# ..          ...        ...    ...             ...           ...  ...   ...
# 33           52 2022-04-30  17:30  Premier League  Matchweek 35  Sat  Away
# 34           54 2022-05-08  16:30  Premier League  Matchweek 36  Sun  Home
# 35           55 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Away
# 36           56 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away
# 37           57 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home
#
# ...

# %%
matches_rolling = df.groupby('team', as_index= False).apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/bj/t8_jdq_92dvc7m96_2p7qkym0000gn/T/ipykernel_80776/757549309.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = df.groupby('team', as_index= False).apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling.index = matches_rolling.index.droplevel(0)

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#       Unnamed: 0       date   time            comp         round  day venue  \
# 0              6 2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home
# 1              7 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away
# 2              9 2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home
# 3             11 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away
# 4             13 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home
# ...          ...        ...    ...             ...           ...  ...   ...
# 1443          37 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home
# 1444          38 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away
# 1445          39 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home
# 1446          40 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home
# 1447          41 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away
#
# ...

# %%
# Retraining the model
def make_predictions(data, predictors):
    train = data[data['date'] < '2022-01-01']
    test = data[data['date'] >= '2022-01-01']

    rf.fit(train[predictors], train['target'])
    prediction = rf.predict(test[predictors])

    combined = pd.DataFrame(dict(actual= test['target'], prediction= prediction))
    combined = combined.merge(data[['date', 'team', 'opponent', 'result']], left_index= True, right_index= True)
    pd.crosstab(index=combined['actual'], columns= combined['prediction'])
    precision = precision_score(test['target'], prediction)

    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors+new_cols)

# %%
precision
# Out:
# 0.5876288659793815

# %%
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 54         0           0 2022-01-01                  Arsenal  Manchester City
# 55         0           0 2022-01-23                  Arsenal          Burnley
# 56         1           1 2022-02-10                  Arsenal           Wolves
# 57         1           1 2022-02-19                  Arsenal        Brentford
# 58         1           1 2022-02-24                  Arsenal           Wolves
# ...      ...         ...        ...                      ...              ...
# 1443       0           0 2022-04-30  Wolverhampton Wanderers         Brighton
# 1444       0           0 2022-05-07  Wolverhampton Wanderers          Chelsea
# 1445       0           0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 1446       0           0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 1447       0           0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result
# 54        L
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key


map_values = {
    'Brighton and Hove Albion': 'Brighton',
    'Manchester United': 'Manchester Utd',
    'Newcastle United': 'Newcastle Utd',
    'Tottenham Hotspur': 'Tottenham',
    'West Ham United': 'West Ham',
    'Wolverhampton Wanderers': 'Wolves'
}

mapping = MissingDict(**map_values)

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
combined.tail()
# Out:
#       actual  prediction       date                     team         opponent  \
# 1443       0           0 2022-04-30  Wolverhampton Wanderers         Brighton
# 1444       0           0 2022-05-07  Wolverhampton Wanderers          Chelsea
# 1445       0           0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 1446       0           0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 1447       0           0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result new_team
# 1443      L   Wolves
# 1444      D   Wolves
# 1445      L   Wolves
# 1446      D   Wolves
# 1447      L   Wolves

# %%
merged = combined.merge(combined, left_on= ['date', 'new_team'], right_on= ['date', 'opponent'])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             0 2022-01-01                  Arsenal
# 1           0             0 2022-01-23                  Arsenal
# 2           1             1 2022-02-10                  Arsenal
# 3           1             1 2022-02-19                  Arsenal
# 4           1             1 2022-02-24                  Arsenal
# ..        ...           ...        ...                      ...
# 389         0             0 2022-04-30  Wolverhampton Wanderers
# 390         0             0 2022-05-07  Wolverhampton Wanderers
# 391         0             0 2022-05-11  Wolverhampton Wanderers
# 392         0             0 2022-05-15  Wolverhampton Wanderers
# 393         0             0 2022-05-22  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0    Manchester City        L    Arsenal         1             1
# ...

# %%
merged[(merged['prediction_x'] == 1) & (merged['prediction_y'] == 0)]['actual_x'].value_counts()
# Out:
# actual_x
# 1    50
# 0    33
# Name: count, dtype: int64

# %%
44/(44 + 38)
# Out:
# 0.5365853658536586

# %% [markdown]
# To extend
# - Scrape more data
# - Use more of the columns to generate prediction
# - Try a different algorithm
# - Integrate more additional data from different leagues
# - Check current team and opponent records
