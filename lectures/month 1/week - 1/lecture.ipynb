# %% [markdown]
# # Data Science
#
# - An incredible skill in 21th centurey.
# - Data science -> (Statistics + Python + Domain Knowledge)
# - Data science -> (Statistics + Python) -> Data Analysis
# - Data science -> Data Analysis -> Data Visiualization
#
#
# ### Introduction to Programming - Python
#
# Python is an object oriented programming language.
#
# That means that any data-type(variable) in python is an object.
#
#
# ### Why is python important for Data Science.
#
# - It is open scource - It has a community of contributors and it si open to contributions
# - It has rich resources for data science.
# - Easy to write and very intuitive.
# - Etc.

# %%
# What is the average of these numbers
number_list = [1, 2, 3]

# Print a list
print(number_list)

# Import Statistics Package
import statistics as st

# Get the average of number_list
print(st.mean(number_list))

# %% [markdown]
# ### Data Structure, Loops, Conditionals, Etc.
#
# Data needs to be organized, managed, stored, accessed and modified efficiently.
#
# Create and use: Lists, Dictionaries, Tuples, Sets
#
# Condtionals: Heuristics(Rules) -> Order of execution.
#
# Conditional statements, Loops(for, while)
#
# Functions: They put everything into one box to perform specific tasks (Sub-routines)
#
#
# ### Operating Systems
#
# - Windows OS
# - Mac OS
# - Linux OS
#
#
# Laptop Specs
# - Ram -> Memory -> Computational Speed Baseline -> 8GB
# - Disk Drive -> HDD / SSD
#
#
# ### Algorithms
#
# A fundamental concept in Data Science.
#
# It plays a crucial role in analyzing, processing and deriving insights.
#
# They are a set of rules that a computer follows while performing a task.
# They are systematic step-by-step formular for problem solving
#
# Algorithms in Data Science:
# - Data sorting, making predictions, find patterns, optimize processes.
# - Importance: Accuracy, Precission, Efficiency, Scaling of models.
#
#
# ### Domain Knowledge
#
# Any area of expertise is a domain where data science can be applied - `Oluwaseyi Aluko`
#
# Appliactions -> Wikipedia search data science applications.
#
# A computer program is said to learn from experience E with respect to some task T and some perfomance merasure P, if its performance on T, as measured by P improves with experience E - `Tom Mitchell, 1997`
#
#
# ### Data
#
# This is the critical element in data science
#
# It is the raw information collected from difference sources
#
# From data: we discover patterns, make prediction and decisions.
#
#
# ##### Types of Data
#
# - Structured - Rectangular -> rows & columns. `Organized` eg. Spreadsheet.
# - Unstructured - no rows & columns -> `Not Organized` eg. audio files, images.
# - Semi_Structured - Hybrid of (structured and ) They do not conform with sql databases  eg. JSON, XML, CSV
#
# ### Poll
#
# ##### The more complex a model the better it will perform? - `False`
#
# A complex model is prone to overfitting: Memorising the training data but doing badly with unseen or new data
#
# Goal of a good model to  generalise well to real world situations
